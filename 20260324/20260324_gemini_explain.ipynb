# %% [markdown]
# # 1.

# %% [markdown]
# ![image.png](attachment:b8f4e72f-64d9-4299-a2d4-2260831e992e.png)

# %% [markdown]
# # 2.

# %% [markdown]
# ![image.png](attachment:84651326-70ac-49d9-8498-7f95745de562.png)

# %% [markdown]
# # 3.

# %% [markdown]
# ![image.png](attachment:2c4484ef-6cd3-4aec-94bc-78424aaf8320.png)
