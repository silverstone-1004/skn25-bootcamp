# %% [markdown]
# # 1.

# %% [markdown]
# ![image.png](attachment:7f629167-e677-4f9b-a292-415cc4c4aa63.png)

# %% [markdown]
# # 2.

# %% [markdown]
# ![image.png](attachment:fefe8146-4f36-4a71-a9b7-778bbd033ad2.png)

# %% [markdown]
# # 3.

# %% [markdown]
# ![image.png](attachment:2b2af89f-f731-4ef6-a44a-a58dcd491f63.png)
