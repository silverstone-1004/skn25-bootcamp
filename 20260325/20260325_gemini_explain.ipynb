# %% [markdown]
# # 1.

# %% [markdown]
# ![image.png](attachment:4923947d-56c8-404d-8142-ed12a779b3a8.png)

# %% [markdown]
# # 2.

# %% [markdown]
# ![image.png](attachment:e2acd490-8b78-45b4-b087-3088d9596d65.png)

# %% [markdown]
# # 3.

# %% [markdown]
# ![image.png](attachment:f6fd6e62-891b-4acd-9334-406cccbd3edb.png)
